# %% [markdown]
# ### 1. OpenCV 에서 이미지를 크롭하여사용하는 경우 좌표계는 어떤식으로 사용되는가?

# %%
import os
import cv2
import matplotlib.pyplot as plt
import numpy as np
import dlib

print("module 로딩완료")
# Out:
# module 로딩완료

# %%
my_image_path = os.getenv('HOME') + '/aiffel/workplace/E03_camera_sticker/images/IU.jpeg'
src = cv2.imread(my_image_path)

dst = src[100:400, 200:600].copy()

plt.imshow(src)
plt.imshow(dst)

#cv2.imshow('adfdf', src)

# %% [markdown]
# 위 상황에서 슬라이싱 좌표는 [y시작:y종료, x시작:x종료] 로 이해 하면 된다.
# 먼저 위와 아래성분(y축성분)을 정해주고 왼쪽, 오른쪽(x축성분)을 정해주면 된다.

# %% [markdown]
# ### 2. 주피터 노트북에서 OpenCV 사용시 주의할 점

# %% [markdown]
# 주피터 노트북에서는 윈도우 창을 사용할 수 없다.
# 때문에 OpcnCV의 cv2.imshow()를 사용할 수 없다.
# 대체 함수로 matplotlib을 사용한다.
#
# plt.imshow(src)

# %% [markdown]
# ### 3. ZIP 함수에 대한 실험들

# %%
print('dlib_rects', dlib_rects)
print('list_landmarks', list_landmarks)

for tmp_a, tmp_b in zip(dlib_rects, list_landmarks):
    print(tmp_a, tmp_b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_205/3618788429.py in <module>
# ----> 1 print('dlib_rects', dlib_rects)
#       2 print('list_landmarks', list_landmarks)
#       3
#       4 for tmp_a, tmp_b in zip(dlib_rects, list_landmarks):
#       5     print(tmp_a, tmp_b)
#
# NameError: name 'dlib_rects' is not defined

# %%
img_sticker.shape[0] # img_sticker.shape은 스티커 이미지의 사이즈를 의미한다. shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_205/2237194926.py in <module>
# ----> 1 img_sticker.shape[0] # img_sticker.shape은 스티커 이미지의 사이즈를 의미한다. shape
#
# NameError: name 'img_sticker' is not defined
