# %% [markdown]
# # Fundamental 14: 고양이상 강아지상

# %% [markdown]
# ### Import Module

# %%
import tensorflow as tf
import tensorflow_datasets as tfds

# 딥러닝 모델들 import
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, MaxPooling2D

import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import warnings
warnings.filterwarnings("ignore")

print(tf.__version__)
print(tfds.__version__)
# Out:
# 2.6.0
# 4.4.0

# %%
import warnings
warnings.filterwarnings("ignore")

print("완료!")
# Out:
# 완료!

# %% [markdown]
# ### 데이터 가져오기

# %%
(raw_train, raw_validation, raw_test), metadata = tfds.load(
    'cats_vs_dogs',
    split=['train[:80%]', 'train[80%:90%]', 'train[90%:]'],
    with_info=True,
    as_supervised=True,
)


#for i in dataset:
#    print(i)
# Out:
# Downloading and preparing dataset 786.68 MiB (download: 786.68 MiB, generated: Unknown size, total: 786.68 MiB) to /aiffel/tensorflow_datasets/cats_vs_dogs/4.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/1 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/23262 [00:00<?, ? examples/s]
# WARNING:absl:1738 images were corrupted and were skipped
# Shuffling cats_vs_dogs-train.tfrecord...:   0%|          | 0/23262 [00:00<?, ? examples/s]
# Dataset cats_vs_dogs downloaded and prepared to /aiffel/tensorflow_datasets/cats_vs_dogs/4.0.0. Subsequent calls will reuse this data.

# %% [markdown]
# ### 데이터셋 확인

# %%
print(raw_train)
print(raw_validation)
print(raw_test)
# Out:
# <PrefetchDataset shapes: ((None, None, 3), ()), types: (tf.uint8, tf.int64)>
# <PrefetchDataset shapes: ((None, None, 3), ()), types: (tf.uint8, tf.int64)>
# <PrefetchDataset shapes: ((None, None, 3), ()), types: (tf.uint8, tf.int64)>

# %% [markdown]
# ### 내부 데이터 확인

# %% [markdown]
# 사진의 사이즈가 전부 제각각이므로
# 모델을 학습시킬 때에는 이미지 사이즈를 통일시켜 주는 작업을 해야한다.

# %%
plt.figure(figsize=(10, 5))

get_label_name = metadata.features['label'].int2str

for idx, (image, label) in enumerate(raw_train.take(10)):  # 10개의 데이터를 가져 옵니다.
    plt.subplot(2, 5, idx+1)
    plt.imshow(image)
    plt.title(f'label {label}: {get_label_name(label)}')
    plt.axis('off')

# %% [markdown]
# ### 이미지를 같은 포맷으로 통일

# %% [markdown]
# (1) format_example() 함수를 사용하는 방법

# %%
IMG_SIZE = 160 # 리사이징할 이미지의 크기

def format_example(image, label):
    image = tf.cast(image, tf.float32)  # image=float(image)같은 타입캐스팅의  텐서플로우 버전입니다.
    image = (image/127.5) - 1 # 픽셀값의 scale 수정
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE))
    return image, label

# %% [markdown]
# ### 원하는 사이즈로 일괄 변환 feat. map()

# %% [markdown]
# 우리는 위에서 리사이징 함수 format_example()를 만들어놓았다.
# 이 함수를 일괄로 각 데이터셋에 적용시켜서 데이터를 변환해야 한다.
# 이때 손쉽게 진행하기 위해서 map() 함수를 사용해서 진행한다.

# %%
train = raw_train.map(format_example)
validation = raw_validation.map(format_example)
test = raw_test.map(format_example)

print(train)
print(validation)
print(test)
# Out:
# <MapDataset shapes: ((160, 160, 3), ()), types: (tf.float32, tf.int64)>
# <MapDataset shapes: ((160, 160, 3), ()), types: (tf.float32, tf.int64)>
# <MapDataset shapes: ((160, 160, 3), ()), types: (tf.float32, tf.int64)>

# %% [markdown]
# ### 이미지 크기 다시 확인해보기

# %% [markdown]
# 이해가 안되는것은 다음행의 의미를 잘 모르겠다는 것
# image = (image + 1) / 2

# %%
plt.figure(figsize=(10, 5))


get_label_name = metadata.features['label'].int2str

for idx, (image, label) in enumerate(train.take(10)):
    plt.subplot(2, 5, idx+1)
    image = (image + 1) / 2
    plt.imshow(image)
    plt.title(f'label {label}: {get_label_name(label)}')
    plt.axis('off')

# %% [markdown]
# 모델을

# %%
model = Sequential([
    Conv2D(filters=16, kernel_size=3, padding='same', activation='relu', input_shape=(160, 160, 3)),
    MaxPooling2D(),
    Conv2D(filters=32, kernel_size=3, padding='same', activation='relu'),
    MaxPooling2D(),
    Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'),
    MaxPooling2D(),
    Flatten(),
    Dense(units=512, activation='relu'),
    Dense(units=2, activation='softmax')
])

# %% [markdown]
# 모델이 학습하는 데에 필요한 "학습률"(learning_rate)이라는 파라미터를 0.0001로 설정해주고, 모델을 compile 하여 학습할 수 있는 형태로 변환

# %%
learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=learning_rate),
              loss=tf.keras.losses.sparse_categorical_crossentropy,
              metrics=['accuracy'])

# %% [markdown]
# ### 모델 학습을 위한 데이터 준비

# %% [markdown]
# 한 스텝에 학습시킬 데이터의 개수인 BATCH_SIZE와 학습 데이터를 적절히 섞어줄 SHUFFLE_BUFFER_SIZE를 설정

# %%
BATCH_SIZE = 32
SHUFFLE_BUFFER_SIZE = 1000

# %%
train_batches = train.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
validation_batches = validation.batch(BATCH_SIZE)
test_batches = test.batch(BATCH_SIZE)

# %%
EPOCHS = 10
history = model.fit(train_batches,
                    epochs=EPOCHS,
                    validation_data=validation_batches)
# Out:
# Epoch 1/10
# 167/582 [=======>......................] - ETA: 36s - loss: 0.0051 - accuracy: 0.9989
# Corrupt JPEG data: 99 extraneous bytes before marker 0xd9
# 199/582 [=========>....................] - ETA: 33s - loss: 0.0074 - accuracy: 0.9980
# Warning: unknown JFIF revision number 0.00
# 209/582 [=========>....................] - ETA: 32s - loss: 0.0070 - accuracy: 0.9981
# Corrupt JPEG data: 396 extraneous bytes before marker 0xd9
# 281/582 [=============>................] - ETA: 26s - loss: 0.0076 - accuracy: 0.9979
# Corrupt JPEG data: 65 extraneous bytes before marker 0xd9
# 489/582 [========================>.....] - ETA: 8s - loss: 0.0078 - accuracy: 0.9979
# Corrupt JPEG data: 2226 extraneous bytes before marker 0xd9
# 502/582 [========================>.....] - ETA: 6s - loss: 0.0076 - accuracy: 0.9979
# Corrupt JPEG data: 128 extraneous bytes before marker 0xd9
# 513/582 [=========================>....] - ETA: 5s - loss: 0.0074 - accuracy: 0.9980
# Corrupt JPEG data: 239 extraneous bytes before marker 0xd9
# 540/582 [==========================>...] - ETA: 3s - loss: 0.0075 - accuracy: 0.9979
# Corrupt JPEG data: 1153 extraneous bytes before marker 0xd9
# 546/582 [===========================>..] - ETA: 3s - loss: 0.0074 - accuracy: 0.9979
# Corrupt JPEG data: 228 extraneous bytes before marker 0xd9
# 580/582 [============================>.] - ETA: 0s - loss: 0.0070 - accuracy: 0.9981
# Corrupt JPEG data: 162 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 252 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 214 extraneous bytes before marker 0xd9
# 582/582 [==============================] - 56s 92ms/step - loss: 0.0070 - accuracy: 0.9981 - val_loss: 1.2982 - val_accuracy: 0.8031
# Epoch 2/10
# 168/582 [=======>......................] - ETA: 36s - loss: 0.0094 - accuracy: 0.9968
# Corrupt JPEG data: 99 extraneous bytes before marker 0xd9
step - loss: 0.0052 - accuracy: 0.9984 - val_loss: 1.5641 - val_accuracy: 0.7941
# Epoch 8/10
# 171/582 [=======>......................] - ETA: 17s - loss: 0.0045 - accuracy: 0.9984
# Corrupt JPEG data: 99 extraneous bytes before marker 0xd9
# 203/582 [=========>....................] - ETA: 16s - loss: 0.0038 - accuracy: 0.9986
# Warning: unknown JFIF revision number 0.00
# 212/582 [=========>....................] - ETA: 15s - loss: 0.0099 - accuracy: 0.9975
# Corrupt JPEG data: 396 extraneous bytes before marker 0xd9
# 284/582 [=============>................] - ETA: 12s - loss: 0.0075 - accuracy: 0.9981
# Corrupt JPEG data: 65 extraneous bytes before marker 0xd9
# 491/582 [========================>.....] - ETA: 4s - loss: 0.0079 - accuracy: 0.9978
# Corrupt JPEG data: 2226 extraneous bytes before marker 0xd9
# 503/582 [========================>.....] - ETA: 4s - loss: 0.0077 - accuracy: 0.9978
# Corrupt JPEG data: 128 extraneous bytes before marker 0xd9
# 514/582 [=========================>....] - ETA: 3s - loss: 0.0076 - accuracy: 0.9979
# Corrupt JPEG data: 239 extraneous bytes before marker 0xd9
# 541/582 [==========================>...] - ETA: 2s - loss: 0.0072 - accuracy: 0.9980
# Corrupt JPEG data: 1153 extraneous bytes before marker 0xd9
# 547/582 [===========================>..] - ETA: 2s - loss: 0.0071 - accuracy: 0.9980
# Corrupt JPEG data: 228 extraneous bytes before marker 0xd9
# 582/582 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9977
# Corrupt JPEG data: 162 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 252 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 214 extraneous bytes before marker 0xd9
# 582/582 [==============================] - 39s 65ms/step - loss: 0.0073 - accuracy: 0.9977 - val_loss: 1.3199 - val_accuracy: 0.7979
# Epoch 9/10
# 168/582 [=======>......................] - ETA: 36s - loss: 0.0051 - accuracy: 0.9989
# Corrupt JPEG data: 99 extraneous bytes before marker 0xd9
# 200/582 [=========>....................] - ETA: 33s - loss: 0.0043 - accuracy: 0.9991
# Warning: unknown JFIF revision number 0.00
# 210/582 [=========>....................] - ETA: 32s - loss: 0.0056 - accuracy: 0.9987
# Corrupt JPEG data: 396 extraneous bytes before marker 0xd9
# 282/582 [=============>................] - ETA: 26s - loss: 0.0044 - accuracy: 0.9990
# Corrupt JPEG data: 65 extraneous bytes before marker 0xd9
# 493/582 [========================>.....] - ETA: 6s - loss: 0.0042 - accuracy: 0.9987
# Corrupt JPEG data: 2226 extraneous bytes before marker 0xd9
# 505/582 [=========================>....] - ETA: 5s - loss: 0.0041 - accuracy: 0.9988
# Corrupt JPEG data: 128 extraneous bytes before marker 0xd9
# 517/582 [=========================>....] - ETA: 4s - loss: 0.0040 - accuracy: 0.9988
# Corrupt JPEG data: 239 extraneous bytes before marker 0xd9
# 543/582 [==========================>...] - ETA: 2s - loss: 0.0038 - accuracy: 0.9988
# Corrupt JPEG data: 1153 extraneous bytes before marker 0xd9
# 549/582 [===========================>..] - ETA: 2s - loss: 0.0038 - accuracy: 0.9989
# Corrupt JPEG data: 228 extraneous bytes before marker 0xd9
# 581/582 [============================>.] - ETA: 0s - loss: 0.0039 - accuracy: 0.9989
# Corrupt JPEG data: 162 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 252 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 214 extraneous bytes before marker 0xd9
# 582/582 [==============================] - 45s 73ms/step - loss: 0.0039 - accuracy: 0.9989 - val_loss: 1.4477 - val_accuracy: 0.7902
# Epoch 10/10
# 170/582 [=======>......................] - ETA: 17s - loss: 0.0015 - accuracy: 0.9998
# Corrupt JPEG data: 99 extraneous bytes before marker 0xd9
# 202/582 [=========>....................] - ETA: 15s - loss: 0.0013 - accuracy: 0.9998
# Warning: unknown JFIF revision number 0.00
# 212/582 [=========>....................] - ETA: 15s - loss: 0.0104 - accuracy: 0.9976
# Corrupt JPEG data: 396 extraneous bytes before marker 0xd9
# 284/582 [=============>................] - ETA: 12s - loss: 0.0078 - accuracy: 0.9982
# Corrupt JPEG data: 65 extraneous bytes before marker 0xd9
# 490/582 [========================>.....] - ETA: 5s - loss: 0.0091 - accuracy: 0.9978
# Corrupt JPEG data: 2226 extraneous bytes before marker 0xd9
# 503/582 [========================>.....] - ETA: 4s - loss: 0.0089 - accuracy: 0.9978
# Corrupt JPEG data: 128 extraneous bytes before marker 0xd9
# 514/582 [=========================>....] - ETA: 3s - loss: 0.0087 - accuracy: 0.9979
# Corrupt JPEG data: 239 extraneous bytes before marker 0xd9
# 541/582 [==========================>...] - ETA: 2s - loss: 0.0083 - accuracy: 0.9980
# Corrupt JPEG data: 1153 extraneous bytes before marker 0xd9
# 547/582 [===========================>..] - ETA: 2s - loss: 0.0082 - accuracy: 0.9980
# Corrupt JPEG data: 228 extraneous bytes before marker 0xd9
# 581/582 [============================>.] - ETA: 0s - loss: 0.0077 - accuracy: 0.9981
# Corrupt JPEG data: 162 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 252 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 214 extraneous bytes before marker 0xd9
# 582/582 [==============================] - 40s 67ms/step - loss: 0.0077 - accuracy: 0.9981 - val_loss: 1.6798 - val_accuracy: 0.7984

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss=history.history['loss']
val_loss=history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(12, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
